# %% [markdown]
# # David Vayman
# # IS362_Project2
#
# ## Leading Causes of Death NYC

# %% [markdown]
# ## Load Csv Into panda

# %%
import pandas as pd
import numpy as np

lcd = pd.read_csv('desktop/New_York_City_Leading_Causes_of_Death.csv')

lcd
# Out:
#       Year                                      Leading Cause Sex  \
# 0     2014                        Diabetes Mellitus (E10-E14)   F
# 1     2011          Cerebrovascular Disease (Stroke: I60-I69)   M
# 2     2008              Malignant Neoplasms (Cancer: C00-C97)   M
# 3     2010              Malignant Neoplasms (Cancer: C00-C97)   F
# 4     2012          Cerebrovascular Disease (Stroke: I60-I69)   M
# 5     2007  Mental and Behavioral Disorders due to Use of ...   M
# 6     2011                                   All Other Causes   F
# 7     2007       Chronic Lower Respiratory Diseases (J40-J47)   F
# 8     2012  Essential Hypertension and Renal Diseases (I10...   F
# 9     2009     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 10    2011       Chronic Lower Respiratory Diseases (J40-J47)   M
# 11    2008          Cerebrovascular Disease (Stroke: I60-I69)   F
# 12    2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# ...

# %% [markdown]
# ## Repalce null values that are portrayed as "." to "NaN"

# %%
lcd = lcd.replace(to_replace='.', value=np.nan)
lcd.head(100)
# Out:
#     Year                                      Leading Cause Sex  \
# 0   2014                        Diabetes Mellitus (E10-E14)   F
# 1   2011          Cerebrovascular Disease (Stroke: I60-I69)   M
# 2   2008              Malignant Neoplasms (Cancer: C00-C97)   M
# 3   2010              Malignant Neoplasms (Cancer: C00-C97)   F
# 4   2012          Cerebrovascular Disease (Stroke: I60-I69)   M
# 5   2007  Mental and Behavioral Disorders due to Use of ...   M
# 6   2011                                   All Other Causes   F
# 7   2007       Chronic Lower Respiratory Diseases (J40-J47)   F
# 8   2012  Essential Hypertension and Renal Diseases (I10...   F
# 9   2009     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 10  2011       Chronic Lower Respiratory Diseases (J40-J47)   M
# 11  2008          Cerebrovascular Disease (Stroke: I60-I69)   F
# 12  2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 13  2010          Cerebrovascular Disease (Stroke: I60-I69)   F
# ...

# %% [markdown]
# ## Change colomn names to make it easier

# %%
column_names = {'Leading Cause': 'Causes',                 
                'Race Ethnicity': 'Ethnicity', 
                'Death Rate': 'rate'}
lcd = lcd.rename (columns=column_names)

lcd.head()
# Out:
#    Year                                     Causes Sex              Ethnicity  \
# 0  2014                Diabetes Mellitus (E10-E14)   F  Other Race/ Ethnicity
# 1  2011  Cerebrovascular Disease (Stroke: I60-I69)   M     White Non-Hispanic
# 2  2008      Malignant Neoplasms (Cancer: C00-C97)   M     Not Stated/Unknown
# 3  2010      Malignant Neoplasms (Cancer: C00-C97)   F               Hispanic
# 4  2012  Cerebrovascular Disease (Stroke: I60-I69)   M     Black Non-Hispanic
#
#   Deaths  rate Age Adjusted Death Rate
# 0     11   NaN                     NaN
# 1    290  21.7                    18.2
# 2     60   NaN                     NaN
# 3   1045  85.9                    98.5
# 4    170  19.9                    23.3

# %%
death = death.apply(lambda x: pd.to_numeric(x, errors='ignore'))
death.dtypes
# Out:
# Year                         int64
# Causes                      object
# Sex                         object
# Ethnicity                   object
# Deaths                     float64
# rate                       float64
# Age Adjusted Death Rate    float64
# dtype: object

# %% [markdown]
# ## Sort out the 2014 Deaths to see where we had the most

# %%
lcd_sort = (lcd
        .sort_values(['Year','Deaths'],ascending =[False,False])
        .set_index ( 'Year'))

lcd_sort
# Out:
#                                                  Causes Sex  \
# Year
# 2014                                   All Other Causes   M
# 2014       Chronic Lower Respiratory Diseases (J40-J47)   M
# 2014     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 2014  Human Immunodeficiency Virus Disease (HIV: B20...   M
# 2014          Cerebrovascular Disease (Stroke: I60-I69)   M
# 2014  Nephritis, Nephrotic Syndrome and Nephrisis (N...   F
# 2014            Influenza (Flu) and Pneumonia (J09-J18)   F
# 2014  Essential Hypertension and Renal Diseases (I10...   M
# 2014                        Diabetes Mellitus (E10-E14)   F
# 2014            Influenza (Flu) and Pneumonia (J09-J18)   F
# 2014                               Septicemia (A40-A41)   M
# 2014                        Diabetes Mellitus (E10-E14)   M
# 2014  Certain Conditions originating in the Perinata...   M
# 2014          Cerebrovascular Disease (Stroke: I60-I69)   F
# ...

# %% [markdown]
# ## 2) Which cause of death had the lowest death rate in 2014?

# %%
lcd_sort = (lcd
        .sort_values(['Year','Deaths'],ascending =[False,True])
        .set_index ( 'Year'))

lcd_sort
# Out:
#                                                  Causes Sex  \
# Year
# 2014  Human Immunodeficiency Virus Disease (HIV: B20...   M
# 2014     Chronic Liver Disease and Cirrhosis (K70, K73)   M
# 2014  Certain Conditions originating in the Perinata...   F
# 2014          Cerebrovascular Disease (Stroke: I60-I69)   F
# 2014  Human Immunodeficiency Virus Disease (HIV: B20...   M
# 2014  Human Immunodeficiency Virus Disease (HIV: B20...   F
# 2014            Influenza (Flu) and Pneumonia (J09-J18)   M
# 2014                        Diabetes Mellitus (E10-E14)   F
# 2014            Influenza (Flu) and Pneumonia (J09-J18)   F
# 2014            Influenza (Flu) and Pneumonia (J09-J18)   M
# 2014          Cerebrovascular Disease (Stroke: I60-I69)   F
# 2014                                   All Other Causes   F
# 2014              Malignant Neoplasms (Cancer: C00-C97)   M
# 2014     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# ...

# %% [markdown]
# ## 3) What are the top 5 causes of death for Asian and Pacific Islander in 2014?

# %%
lcd_sort = (lcd
        .sort_values(['Year','Ethnicity','Deaths'],ascending =[False,True,False]) 
        .set_index ( 'Causes'))

lcd_sort
# Out:
#                                                     Year Sex  \
# Causes
# Chronic Lower Respiratory Diseases (J40-J47)        2014   M
# Cerebrovascular Disease (Stroke: I60-I69)           2014   M
# Influenza (Flu) and Pneumonia (J09-J18)             2014   F
# Diabetes Mellitus (E10-E14)                         2014   M
# Accidents Except Drug Posioning (V01-X39, X43, ...  2014   M
# Malignant Neoplasms (Cancer: C00-C97)               2014   M
# Diseases of Heart (I00-I09, I11, I13, I20-I51)      2014   M
# Malignant Neoplasms (Cancer: C00-C97)               2014   F
# Diabetes Mellitus (E10-E14)                         2014   F
# Intentional Self-Harm (Suicide: X60-X84, Y87.0)     2014   M
# Diseases of Heart (I00-I09, I11, I13, I20-I51)      2014   F
# All Other Causes                                    2014   M
# Accidents Except Drug Posioning (V01-X39, X43, ...  2014   F
# Chronic Lower Respiratory Diseases (J40-J47)        2014   F
# ...
